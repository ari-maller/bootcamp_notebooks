# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
N=100000
x=np.random.normal(size=N)
y=np.random.normal(size=N)
hist,xedges,yedges=np.histogram2d(x,y,bins=25)
print(hist.shape)
# Out:
# (25, 25)

# %%
plt.imshow(hist)

# %%
plt.imshow(hist,extent=[xedges[0],xedges[-1],yedges[0],yedges[-1]])

# %%
hist2,xedges2,yedges2=np.histogram2d(x,y,bins=25,range=[[-2,2],[-2,2]])
plt.imshow(hist2,extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])

# %%
plt.imshow(hist2,cmap='plasma',extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])

# %%
plt.imshow(hist2,cmap='coolwarm',extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])

# %%
plt.imshow(hist2,cmap='brg',extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])
plt.colorbar()

# %%
x=0.5*(xedges2[1:]+xedges[0:-1])
y=0.5*(yedges2[1:]+yedges[0:-1])
plt.contour(x,y,hist2)

# %%
f,ax=plt.subplots(figsize=(4,4))
ax.contour(hist2,[100,200,300,400],extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])

# %%
f,ax=plt.subplots(figsize=(4,4))
cs=ax.contour(hist2,[100,200,300,400],extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])
ax.clabel(cs,inline=1,fontsize=10)
# Out:
# <a list of 4 text.Text objects>

# %%
f,ax=plt.subplots(figsize=(4,4))
cs=ax.contour(hist2,[100,200,300,400],colors=['b','c','r','m'],extent=[xedges2[0],xedges2[-1],yedges2[0],yedges2[-1]])
ax.clabel(cs,inline=1,fontsize=10,fmt='%d')
# Out:
# <a list of 4 text.Text objects>

# %% [markdown]
# ###Exercise 1
# Grab the file http://www.astropy.org/astropy-data/tutorials/FITS-images/M13_blue_0001.fits from astropy. Read the file and plot it using imshow and as a contour map side by side.

# %%
import astropy 
from astropy.utils import data
from astropy.io import fits
image_file = astropy.utils.data.get_pkg_data_filename('tutorials/FITS-images/HorseHead.fits')
image_data = astropy.io.fits.getdata(image_file, ext=0)
image_data.shape
# Out:
# (893, 891)

# %%
plt.imshow(image_data)

# %%
plt.imshow(np.transpose(image_data))

# %%
plt.imshow(np.transpose(image_data),origin='lower')

# %%
plt.plot(image_data[:,400])
